# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
from typing import Tuple

# %%
data_dir = r"D:\riwa_v2"
images_dir = os.path.join(data_dir, r"images")
masks_dir = os.path.join(data_dir, r"masks")

train_data = []
for img, msk in zip(os.listdir(images_dir), os.listdir(masks_dir)):
   train_data.append({
       "image": os.path.join(images_dir, img),
       "annotation": os.path.join(masks_dir, msk)
   })

val_imgs = r"D:\riwa_v2\validation\images"
val_msks = r"D:\riwa_v2\validation\masks"
val_data = []
for img, msk in zip(os.listdir(val_imgs), os.listdir(val_msks)):
   val_data.append({
      "image": os.path.join(val_imgs, img),
      "annotation": os.path.join(val_msks, msk)
   })

test_dir = r"D:\riwa_v2\test"
t_img = os.path.join(test_dir, "images")
t_msk = os.path.join(test_dir, "masks")

test_data = []
for img, msk in zip(os.listdir(t_img), os.listdir(t_msk)):
   test_data.append({
       "image": os.path.join(t_img, img),
       "annotation": os.path.join(t_msk, msk)
   })

# %%
def load_image_and_mask(image_path: str, mask_path: str) -> Tuple[np.ndarray, np.ndarray]:
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)

    if (mask is None) or (image is None):
        raise FileNotFoundError(f"file not found")
    
    return image, mask

def crop_image(
    dataset: dict,
    index: int,
    min_true_ratio: float,
    max_true_ratio: float,
    min_crop_size: Tuple[int, int],
    max_crop_size: Tuple[int, int],
    max_trial: int,
    save_path: str = r"D:\augmentation",
    show_result: bool = False
) -> Tuple[np.ndarray, np.ndarray]:
    """
    최소/최대 크기 범위와 참 값 비율 조건을 만족하도록 이미지를 자름.

    Parameters:
        image (np.ndarray): 원본 이미지 배열 (H, W, C).
        mask (np.ndarray): 마스크 배열 (H, W), 값은 0 또는 1.
        min_true_ratio (float): 포함해야 할 최소 참 값 비율 (0~1).
        min_crop_size (Tuple[int, int]): 최소 crop 크기 (min_height, min_width).
        max_crop_size (Tuple[int, int]): 최대 crop 크기 (max_height, max_width).

    Returns:
        cropped_image (np.ndarray): 조건을 만족하는 crop된 이미지 배열.
        cropped_mask (np.ndarray): 조건을 만족하는 crop된 마스크 배열.
    """
    img_name, msk_name = dataset[index].values()
    save_img = save_path + f"\\images\\{img_name.split('\\')[-1].split('.')[0]}_crop.jpg"
    save_msk = save_path + f"\\masks\\{msk_name.split('\\')[-1].split('.')[0]}_crop.png"
    image, mask = load_image_and_mask(img_name, msk_name)

    img_h, img_w = mask.shape
    min_h, min_w = min_crop_size
    max_h, max_w = max_crop_size

    if min_h > img_h or min_w > img_w: return
    
    if max_h > img_h: max_h = img_h
    if max_w > img_w: max_w = img_w
    
    if min_h > max_h or min_w > max_w: return
    
    for _ in range(max_trial):
        # 랜덤한 crop 크기 선택
        crop_h = np.random.randint(min_h, max_h + 1)
        crop_w = np.random.randint(min_w, max_w + 1)

        # 랜덤한 crop 시작 좌표 선택
        top = np.random.randint(0, img_h - crop_h + 1)
        left = np.random.randint(0, img_w - crop_w + 1)
        bottom = top + crop_h
        right = left + crop_w

        # 해당 영역의 마스크 추출
        cropped_mask = mask[top:bottom, left:right]

        mask_val = cropped_mask.astype(bool, copy=True)
        true_ratio = np.mean(mask_val)

        # 비율 조건 확인
        if true_ratio >= min_true_ratio and true_ratio <= max_true_ratio:
            cropped_image = image[top:bottom, left:right]
            cv2.imwrite(save_img, cropped_image)
            cv2.imwrite(save_msk, (cropped_mask).astype(np.uint8))
            if show_result:
                plt.subplot(121)
                plt.imshow(cropped_image)
                plt.subplot(122)
                plt.imshow(cropped_mask)
            return 

    # 조건을 만족하는 crop을 찾지 못한 경우
    print(f"failed to crop image {index}")

# %%
# 최소 및 최대 크기 범위와 최소 참 값 비율 설정
min_crop_size = (400, 400)  # 최소 크기
max_crop_size = (1024, 1024)  # 최대 크기
min_true_ratio = 0.3  # 최소 참 값 비율
max_true_ratio = 0.7  # 최대 참 값 비율
max_trial = 100

for i, _ in enumerate(train_data):
    crop_image(
        train_data, i, min_true_ratio, max_true_ratio, min_crop_size, max_crop_size, max_trial
    )
# Out:
# failed to crop image 3
# failed to crop image 5
# failed to crop image 14
# failed to crop image 22
# failed to crop image 26
# failed to crop image 31
# failed to crop image 37
# failed to crop image 40
# failed to crop image 47
# failed to crop image 48
# failed to crop image 49
# failed to crop image 59
# failed to crop image 61
# failed to crop image 62
# failed to crop image 63
# failed to crop image 64
# failed to crop image 67
# failed to crop image 68
# failed to crop image 70
# failed to crop image 71
# failed to crop image 72
# failed to crop image 73
# failed to crop image 74
# failed to crop image 75
# failed to crop image 85
# failed to crop image 86
# failed to crop image 89
# failed to crop image 95
# failed to crop image 96
# failed to crop image 107
# failed to crop image 108
# failed to crop image 109
# failed to crop image 110
# failed to crop image 112
# failed to crop image 113
# failed to crop image 114
# failed to crop image 115
# failed to crop image 117
# failed to crop image 119
# failed to crop image 122
# failed to crop image 124
# failed to crop image 125
# failed to crop image 133
# failed to crop image 138
# failed to crop image 141
# failed to crop image 142
# failed to crop image 144
# failed to crop image 145
# failed to crop image 146
# failed to crop image 155
# failed to crop image 157
# failed to crop image 164
# failed to crop image 173
# failed to crop image 175
# failed to crop image 176
# failed to crop image 177
# failed to crop image 178
# failed to crop image 180
# failed to crop image 186
# failed to crop image 189
# failed to crop image 191
# failed to crop image 192
# failed to crop image 194
# failed to crop image 195
# failed to crop image 198
# failed to crop image 199
# failed to crop image 201
# failed to crop image 211
# failed to crop image 212
# failed to crop image 213
# failed to crop image 214
# failed to crop image 216
# failed to crop image 217
# failed to crop image 221
# failed to crop image 223
# failed to crop image 231
# failed to crop image 233
# failed to crop image 244
# failed to crop image 246
# failed to crop image 249
# failed to crop image 254
# failed to crop image 257
# failed to crop image 271
# failed to crop image 275
# failed to crop image 278
# failed to crop image 281
# failed to crop image 285
# failed to crop image 287
# failed to crop image 289
# failed to crop image 290
# failed to crop image 291
# failed to crop image 301
# failed to crop image 303
# failed to crop image 305
# failed to crop image 306
# failed to crop image 310
# failed to crop image 311
# failed to crop image 312
# failed to crop image 313
# failed to crop image 319
# failed to crop image 321
# failed to crop image 324
# failed to crop image 327
# failed to crop image 335
# failed to crop image 336
# failed to crop image 340
# failed to crop image 341
# failed to crop image 343
# failed to crop image 344
# failed to crop image 345
# failed to crop image 346
# failed to crop image 347
# failed to crop image 352
# failed to crop image 354
# failed to crop image 355
# failed to crop image 358
# failed to crop image 359
# failed to crop image 360
# failed to crop image 364
# failed to crop image 366
# failed to crop image 370
# failed to crop image 374
# failed to crop image 382
# failed to crop image 383
# failed to crop image 384
# failed to crop image 386
# failed to crop image 391
# failed to crop image 392
# failed to crop image 396
# failed to crop image 398
# failed to crop image 400
# failed to crop image 401
# failed to crop image 404
# failed to crop image 406
# failed to crop image 409
# failed to crop image 413
# failed to crop image 414
# failed to crop image 419
# failed to crop image 420
# failed to crop image 421
# failed to crop image 423
# failed to crop image 428
# failed to crop image 431
# failed to crop image 435
# failed to crop image 440
# failed to crop image 441
# failed to crop image 447
# failed to crop image 453
# failed to crop image 459
# failed to crop image 463
# failed to crop image 464
# failed to crop image 465
# failed to crop image 466
# failed to crop image 480
# failed to crop image 481
# failed to crop image 483
# failed to crop image 484
# failed to crop image 489
# failed to crop image 490
# failed to crop image 491
# failed to crop image 499
# failed to crop image 501
# failed to crop image 502
# failed to crop image 503
# failed to crop image 504
# failed to crop image 506
# failed to crop image 510
# failed to crop image 529
# failed to crop image 532
# failed to crop image 546
# failed to crop image 548
# failed to crop image 550
# failed to crop image 552
# failed to crop image 553
# failed to crop image 554
# failed to crop image 555
# failed to crop image 556
# failed to crop image 558
# failed to crop image 559
# failed to crop image 563
# failed to crop image 564
# failed to crop image 570
# failed to crop image 575
# failed to crop image 576
# failed to crop image 578
# failed to crop image 579
# failed to crop image 580
# failed to crop image 581
# failed to crop image 589
# failed to crop image 590
# failed to crop image 592
# failed to crop image 593
# failed to crop image 598
# failed to crop image 605
# failed to crop image 606
# failed to crop image 607
# failed to crop image 610
# failed to crop image 611
# failed to crop image 614
# failed to crop image 617
# failed to crop image 628
# failed to crop image 629
# failed to crop image 630
# failed to crop image 635
# failed to crop image 661
# failed to crop image 668
# failed to crop image 673
# failed to crop image 685
# failed to crop image 710
# failed to crop image 711
# failed to crop image 716
# failed to crop image 725
# failed to crop image 727
# failed to crop image 736
# failed to crop image 739
# failed to crop image 765
# failed to crop image 766
# failed to crop image 767
# failed to crop image 768
# failed to crop image 827
# failed to crop image 828
# failed to crop image 829
# failed to crop image 835
# failed to crop image 837
# failed to crop image 841
# failed to crop image 843
# failed to crop image 847
# failed to crop image 856
# failed to crop image 867
# failed to crop image 868
# failed to crop image 880
# failed to crop image 893
# failed to crop image 895
# failed to crop image 929
# failed to crop image 934
# failed to crop image 954
# failed to crop image 977
# failed to crop image 982
# failed to crop image 1005
# failed to crop image 1006
# failed to crop image 1009
# failed to crop image 1021
# failed to crop image 1065
# failed to crop image 1066
# failed to crop image 1067
# failed to crop image 1071
# failed to crop image 1073
# failed to crop image 1075
# failed to crop image 1079
# failed to crop image 1081
# failed to crop image 1084
# failed to crop image 1088
# failed to crop image 1090
# failed to crop image 1092
# failed to crop image 1093
# failed to crop image 1095
# failed to crop image 1099
# failed to crop image 1106
# failed to crop image 1108
# failed to crop image 1110
# failed to crop image 1111
# failed to crop image 1116
# failed to crop image 1117
# failed to crop image 1119
# failed to crop image 1120
# failed to crop image 1128
# failed to crop image 1129
# failed to crop image 1130
# failed to crop image 1132
# failed to crop image 1134
# failed to crop image 1135
# failed to crop image 1137
# failed to crop image 1138
# failed to crop image 1139
# failed to crop image 1140

# %%
# Horizontal Flip
save_path = r"D:\augmentation"

for i, d in enumerate(train_data):
    image_path, mask_path = d.values()
    image, mask = load_image_and_mask(image_path, mask_path)
    
    hflip_image = cv2.flip(image, 1)
    hflip_mask = cv2.flip(mask, 1)

    flip_img_path = save_path + "\\images\\" + image_path.split("\\")[-1].split(".")[0] + "_flip.jpg"
    flip_msk_path = save_path + "\\masks\\" + image_path.split("\\")[-1].split(".")[0] + "_flip.png"

    cv2.imwrite(flip_img_path, hflip_image)
    cv2.imwrite(flip_msk_path, hflip_mask)

# %%
import random

# %%
# Gaussian Blur
for i, d in enumerate(train_data):
    image_path, mask_path = d.values()
    image, mask = load_image_and_mask(image_path, mask_path)
    
    blur_image = cv2.GaussianBlur(image, (0, 0), random.uniform(2, 3))
    blur_mask = mask

    blur_img_path = save_path + "\\images\\" + image_path.split("\\")[-1].split(".")[0] + "_blur.jpg"
    blur_msk_path = save_path + "\\masks\\" + image_path.split("\\")[-1].split(".")[0] + "_blur.png"

    cv2.imwrite(blur_img_path, blur_image)
    cv2.imwrite(blur_msk_path, blur_mask)

# %%
import albumentations as A

save_path = r"D:\augmentation"

# rainy noise
transform = A.Compose(
    [A.RandomRain(brightness_coefficient=0.9, drop_width=1, blur_value=5, p=1)],
)
for i, d in enumerate(train_data):
    image_path, mask_path = d.values()
    image, mask = load_image_and_mask(image_path, mask_path)

    rain_image = transform(image=image)
    rain_mask = mask

    plt.imshow(rain_image['image'])
    break
    # rain_img_path = save_path + "\\images\\" + image_path.split("\\")[-1].split(".")[0] + "_rain.jpg"
    # rain_msk_path = save_path + "\\masks\\" + image_path.split("\\")[-1].split(".")[0] + "_rain.png"

    # cv2.imwrite(rain_img_path, rain_image)
    # cv2.imwrite(rain_msk_path, rain_mask)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 11
#       9 for i, d in enumerate(train_data):
#      10     image_path, mask_path = d.values()
# ---> 11     image, mask = load_image_and_mask(image_path, mask_path)
#      13     rain_image = transform(image=image)
#      14     rain_mask = mask
#
# Cell In[6], line 3, in load_image_and_mask(image_path, mask_path)
#       1 def load_image_and_mask(image_path: str, mask_path: str) -> Tuple[np.ndarray, np.ndarray]:
#       2     image = cv2.imread(image_path, cv2.IMREAD_COLOR)
# ----> 3     mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
#       5     if (mask is None) or (image is None):
#       6         raise FileNotFoundError(f"file not found")
#
# KeyboardInterrupt:

# %%
# foggy noise
